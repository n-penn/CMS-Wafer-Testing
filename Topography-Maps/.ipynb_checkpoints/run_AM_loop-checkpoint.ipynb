# %%
import subprocess
import os

root_path = os.path.expanduser("~/Desktop/log_files/")
for root, dirs, files in os.walk(root_path):
    for file_name in files:
        file_path = os.path.join(root, file_name)

        # Command to execute your Python script (replace with your script path and any arguments)
        script_path = "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py"
        command = ['python3.9', script_path, file_path]

        # Run the script as a subprocess
        process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

        # Wait for the process to complete and capture output (optional)
        stdout, stderr = process.communicate()

        # Check if there was an error
        if process.returncode != 0:
            print(f"Error running script: {stderr.decode('utf-8')}")
        else:
            print(f"Script ran successfully: {stdout.decode('utf-8')}")
# Out:
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 69, in <module>
#     min_height = min(contactheight)
# ValueError: min() arg is an empty sequence
#
# Script ran successfully: Range: 16024um to 16038um (14um)
# Bins:
#  - Low (l):          16024-16027um
#  - Medium low (ml):  16027-16031um
#  - Medium high (mh): 16031-16034um
#  - High (h):         16034-16038um
# Mean: 16032.485um
# Median: 16032um
# Mode: 16036um
# Chips at median height: 81, A3, B4, A6, B6, C6, C7, B7, 47, 37, 27, 18, 78, 98, A9, 99, 59, 3D, 6F
# Chips at maximum height: 3A, 4A, 3B, 4C, 5C, 5D, 4D, 5E
# Chips at minimum height: 43
# + Saved wafer map: /nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/Topography_map_NC0W14-07G5.pdf
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 26, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 26, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Script ran successfully: Range: 16022um to 16036um (14um)
# Bins:
#  - Low (l):          16022-16025um
#  - Medium low (ml):  16025-16029um
#  - Medium high (mh): 16029-16032um
#  - High (h):         16032-16036um
# Mean: 16030.235um
# Median: 16030um
# Mode: 16032um
# Chips at median height: 71, A3, B4, 26, B6, C6, C7, B7, 37, 27, 18, 78, 98, A8, A9, 99, 89, 79, 8B, 7B, 6B
# Chips at maximum height: D8, 29, 2A, 3A, 4A, 3B, 3C, 4D
# Chips at minimum height: 33
# + Saved wafer map: /nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/Topography_map_NC0W14-05A4.pdf
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 26, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 26, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 26, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Script ran successfully: Range: 15996um to 16008um (12um)
# Bins:
#  - Low (l):          15996-15999um
#  - Medium low (ml):  15999-16002um
#  - Medium high (mh): 16002-16005um
#  - High (h):         16005-16008um
# Mean: 16002.706um
# Median: 16002um
# Mode: 16002um
# Chips at median height: 83, 84, B4, A5, 95, A6, B6, C6, B7, A7, 17, 28, 38, 48, 58, 68, 78, 88, 98, A8, B8, A9, 89, 69, 59, 49, 39, 29, 7A, 8A, 9A, 8B, 7B
# Chips at maximum height: 3C, 4C, 5C, AD, 4D, 3D, 4E
# Chips at minimum height: 43, 33, 35, 25
# + Saved wafer map: /nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/Topography_map_NC0W14-03B6.pdf
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 26, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Script ran successfully: Range: 15982um to 16012um (30um)
# Bins:
#  - Low (l):          15982-15989um
#  - Medium low (ml):  15989-15997um
#  - Medium high (mh): 15997-16004um
#  - High (h):         16004-16012um
# Mean: 15997.265um
# Median: 15997um
# Mode: 15988um
# Calculated median not in data set. Chips at next highest height (15998um): ['18', '28', '38', '48', '98', 'A8', 'B8', '89', '79', '59']
# Chips at maximum height: 4D, 3D, 5E
# Chips at minimum height: 33
# + Saved wafer map: /nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/Topography_map_NC0W14-06H2.pdf
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 26, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Script ran successfully: Range: 15970um to 16002um (32um)
# Bins:
#  - Low (l):          15970-15978um
#  - Medium low (ml):  15978-15986um
#  - Medium high (mh): 15986-15994um
#  - High (h):         15994-16002um
# Mean: 15986.382um
# Median: 15987um
# Mode: 15970um
# Calculated median not in data set. Chips at next highest height (15988um): ['42', '98', 'B8', '99', '79']
# Chips at maximum height: 3C, AD, 4D, 3D, 4E, 5E, 6E, 8E, 6F
# Chips at minimum height: 53, 43, 33, 24, 34, 44, 54, 64, 74, 84, 94, 85, 75, 65, 55, 45, 35, 25
# + Saved wafer map: /nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/Topography_map_NC0W14-04B1.pdf
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 26, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 26, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/topography_map.py", line 26, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
