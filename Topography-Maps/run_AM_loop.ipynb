# %%
import subprocess
import os

root_path = os.path.expanduser("~/Desktop/log_files/")
for root, dirs, files in os.walk(root_path):
    for file_name in files:
        file_path = os.path.join(root, file_name)

        # Command to execute your Python script (replace with your script path and any arguments)
        script_path = "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py"
        command = ['python3.9', script_path, file_path]

        # Run the script as a subprocess
        process = subprocess.Popen(command, stdout=subprocess.PIPE, stderr=subprocess.PIPE)

        # Wait for the process to complete and capture output (optional)
        stdout, stderr = process.communicate()

        # Check if there was an error
        if process.returncode != 0:
            print(f"Error running script: {stderr.decode('utf-8')}")
        else:
            print(f"Script ran successfully: {stdout.decode('utf-8')}")
# Out:
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 90, in <module>
#     min_height = int(min(asymmetries))
# ValueError: min() arg is an empty sequence
#
# Script ran successfully: Range: -4um to 6um (10um)
# Bins:
#  - Low (l):          -4um or less
#  - Medium low (ml):  2um
#  - Medium (m):       0um
#  - Medium high (mh): 2um
#  - High (h):         4um or higher
# Mean: 2.559um
# Median: 2um
# Mode: 2um
# Chips at median height(2um): 81, 42, 52, 92, B3, 93, 73, 53, 33, 54, 74, 84, 94, A5, 95, 85, 55, 35, 26, 36, 66, 76, 86, 96, A6, B6, 87, 67, 27, 28, 78, 98, A8, C9, B9, 99, 89, 59, 8A, 9A, AA, BA, CB, BB, AB, 9B, 7B, 6B, 3C, 8C, 9C, AC, BD, AD, 4E, 8E, 6F
# Chips at maximum asymmetry (6um): 24, 48, 58, 49, 4A, 5C, 5D, 4D, 5E, 7E, 9E, 7F
# Chips at minimum asymmetry (-4um): 19
# + Saved wafer map: /nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/Asymmetry_map_NC0W14-07G5.png
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 27, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 27, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Script ran successfully: Range: -4um to 6um (10um)
# Bins:
#  - Low (l):          -4um or less
#  - Medium low (ml):  2um
#  - Medium (m):       0um
#  - Medium high (mh): 2um
#  - High (h):         4um or higher
# Mean: 2.5um
# Median: 2um
# Mode: 2um
# Chips at median height(2um): 71, 42, 52, 62, 72, 82, B3, A3, 93, 63, 53, 33, 24, 64, 74, 94, B4, A5, 95, 45, 36, 46, 66, 86, B6, B7, 97, 67, 47, 37, 88, A8, B8, B9, 99, 89, 79, 6A, 8A, AA, BA, 9B, 8B, 7B, 6B, 2B, 8C, AC, BD, AD, 9D, 6D, 3D, 6E, 8E, 6F
# Chips at maximum asymmetry (6um): 44, 26, 56, 48, 69, 49, 29, 2A, 4A, 3B, 3C, 5D, 4D, 5E, 7E
# Chips at minimum asymmetry (-4um): 19
# + Saved wafer map: /nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/Asymmetry_map_NC0W14-05A4.png
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 27, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 27, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 27, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Script ran successfully: Range: -8um to 2um (10um)
# Bins:
#  - Low (l):          -4um or less
#  - Medium low (ml):  2um
#  - Medium (m):       0um
#  - Medium high (mh): 2um
#  - High (h):         4um or higher
# Mean: -1.191um
# Median: -2um
# Mode: -2um
# Chips at median height(-2um): 61, 42, 52, 62, 72, 82, A2, A3, 93, 83, 73, 53, 33, 24, 54, 94, 95, 85, 65, 55, 45, 36, 76, 86, 96, A6, B6, C6, B7, 97, 87, 67, 47, 58, 68, 78, 88, 98, A8, C9, B9, A9, 89, 59, BA, BB, 9B, 6B, 4B, 4C, 7C, 8C, AC, AD, 9D, 7D, 6D, 4E, 8E, 6F
# Chips at maximum asymmetry (2um): 26, 48, D8, 6A, CB, 3B, 3C, 5C, 5D, 4D, 7F
# Chips at minimum asymmetry (-8um): 17
# + Saved wafer map: /nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/Asymmetry_map_NC0W14-03B6.png
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 27, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Script ran successfully: Range: -6um to 4um (10um)
# Bins:
#  - Low (l):          -4um or less
#  - Medium low (ml):  2um
#  - Medium (m):       0um
#  - Medium high (mh): 2um
#  - High (h):         4um or higher
# Mean: -0.971um
# Median: 0um
# Mode: 0um
# Chips at median height(0um): 81, 33, 44, 64, 74, C5, 35, 25, 36, 46, 56, 66, 87, 77, 57, 47, 37, 58, 68, 88, 99, 79, 59, 39, 3A, 5A, 6A, 9A, AA, CB, AB, 7B, 6B, 5B, 2B, 4C, 5C, 6C, 7C, 8C, 9C, BC, 8D, 7D, 6D, 3D, 4E, 6E, 7E, 9E
# Chips at maximum asymmetry (4um): 49, 29, 5D
# Chips at minimum asymmetry (-6um): D8
# + Saved wafer map: /nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/Asymmetry_map_NC0W14-06H2.png
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 27, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Script ran successfully: no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# no match
# Range: -6um to 4um (10um)
# Bins:
#  - Low (l):          -4um or less
#  - Medium low (ml):  2um
#  - Medium (m):       0um
#  - Medium high (mh): 2um
#  - High (h):         4um or higher
# Mean: -1.407um
# Median: -2um
# Mode: 0um
# Chips at median height(-2um): 81, 83, 63, 53, 43, 44, 94, A4, B4, B5, A5, 45, 25, C7, B7, 87, 47, 27, 17, 38, C9, B9, A9, 89, 69, 39, 19, CB, 9B, 5B, 5C
# Chips at maximum asymmetry (4um): 68, A8
# Chips at minimum asymmetry (-6um): 61, A2, 24, 85, 77, 57, 78
# + Saved wafer map: /nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/Asymmetry_map_NC0W14-04B1.png
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 27, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 27, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
#
# Error running script: Traceback (most recent call last):
#   File "/nfshome/natpenn/Desktop/CMS-Wafer-Testing/Topography-Maps/asymmetry_map.py", line 27, in <module>
#     log_content = file.readlines()
#   File "/usr/lib64/python3.9/codecs.py", line 322, in decode
#     (result, consumed) = self._buffer_decode(data, self.errors, final)
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xff in position 0: invalid start byte
